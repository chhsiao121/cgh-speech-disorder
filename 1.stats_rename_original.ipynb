# %%
import pandas as pd
import os
import shutil
import json

# %%
WORDCARD = "data_0327word"
DATE = "0401_0811"

# %%
WORDCARD = "data_0820word"
DATE = "0820_0916"

# %%
STATPATH = '/D/TWCC/work/cgh_2022/jsonmv/stat/'+WORDCARD+'/'+DATE+'/compareST_'+DATE+'.csv'


DATASET = "original"

DATASETPATH = '/D/TWCC/work/cgh_2022/data/'+WORDCARD+'/use-three-ST-label-dataset_'+DATE+'/' + DATASET+'/'

SYLLABLEPATH = DATASETPATH + 'syllable/'
WORDPATH = DATASETPATH + 'word/'

FCDPPATH = DATASETPATH + 'fcdp/'
FCDPSYLLABLEPATH = FCDPPATH + 'syllable/'
FCDPWORDPATH = FCDPPATH + 'word/'

DATAPATH = '/D/TWCC/data2022_ori/'+WORDCARD+'/'+DATE+'/'
SEED = 42

# %%
if not os.path.exists(DATASETPATH):
    os.makedirs(DATASETPATH)
    print(f"making dir {DATASETPATH}")
if not os.path.isdir(SYLLABLEPATH):
    os.makedirs(SYLLABLEPATH)
    print(f"making dir {SYLLABLEPATH}")

if not os.path.isdir(WORDPATH):
    os.makedirs(WORDPATH)
    print(f"making dir {WORDPATH}")

if not os.path.isdir(FCDPSYLLABLEPATH):
    os.makedirs(FCDPSYLLABLEPATH)
    print(f"making dir {FCDPSYLLABLEPATH}")

if not os.path.isdir(FCDPWORDPATH):
    os.makedirs(FCDPWORDPATH)
    print(f"making dir {FCDPWORDPATH}")

# %%
class_dict = {
    "塞音化": 1,
    "母音化": 2,
    "母音省略": 3,
    "舌前音化": 4,
    "舌根音化": 5,
    "不送氣音化": 6,
    "聲隨韻母": 7,
    "邊音化": 8,
    "齒間音": 9,
    "子音省略": 10,
    "擦音化": 11,
    "介音省略": 12,
    "塞擦音化": 13,
    "複韻母省略": 14,
    "其他": 15,
    "正確": 16,
    "雜訊無法辨識": 17
}
class_name = ["塞音化", "母音化", "母音省略", "舌前音化", "舌根音化", "不送氣音化", "聲隨韻母",
              "邊音化", "齒間音", "子音省略", "擦音化", "介音省略", "塞擦音化", "複韻母省略", "其他", "正確", "雜訊無法辨識"]

# %%
from ast import literal_eval
df_stat = pd.read_csv(STATPATH, index_col=0)

for case in df_stat.columns.tolist(): 
    for wordcard in df_stat.index.tolist(): 
        if not df_stat[case][wordcard]: 
            pass
        elif (df_stat[case][wordcard] != df_stat[case][wordcard]): 
            pass 
        else: 
            df_stat[case][wordcard] = literal_eval(df_stat[case][wordcard]) # convert to list

# %%
df_stat.head(20)
# Out:
#                     2022.04.01.13.12.28_477493581  \
# wordcard03_01.wav                            [16]
# wordcard03_01_1.wav                          [16]
# wordcard03_01_2.wav                          [16]
# wordcard03_02.wav                            [16]
# wordcard03_02_1.wav                          [16]
# wordcard03_02_2.wav                          [16]
# wordcard03_03.wav                             [5]
# wordcard03_03_1.wav                           [5]
# wordcard03_03_2.wav                          [16]
# wordcard03_04.wav                            [16]
# wordcard03_04_1.wav                          [16]
# wordcard03_04_2.wav                          [16]
# wordcard03_05.wav                             [5]
# wordcard03_05_1.wav                           [5]
# wordcard03_05_2.wav                          [16]
# wordcard03_06.wav                            [16]
# wordcard03_06_1.wav                          [16]
# wordcard03_06_2.wav                          [16]
# wordcard03_07.wav                            [16]
# wordcard03_07_1.wav                          [16]
#
#                     2022.04.06.10.08.07_56554239 2022.04.06.14.09.10_42091033  \
# wordcard03_01.wav                           [16]                          [4]
# wordcard03_01_1.wav                         [16]                         [16]
# wordcard03_01_2.wav                         [11]                          [4]
# wordcard03_02.wav                           [16]                          [4]
# wordcard03_02_1.wav                         [16]                         [16]
# wordcard03_02_2.wav                         [16]                          [4]
# wordcard03_03.wav                           [16]                          NaN
# wordcard03_03_1.wav                         [16]                          NaN
# wordcard03_03_2.wav                         [16]                          NaN
# wordcard03_04.wav                           [16]                          NaN
# wordcard03_04_1.wav                         [16]                          NaN
# wordcard03_04_2.wav                         [16]                          NaN
# wordcard03_05.wav                           [16]                          NaN
# wordcard03_05_1.wav                         [16]                          NaN
# wordcard03_05_2.wav                         [16]                          NaN
# wordcard03_06.wav                           [16]                          NaN
# wordcard03_06_1.wav                         [16]                          NaN
# wordcard03_06_2.wav                         [16]                          NaN
# wordcard03_07.wav                           [16]                          NaN
# wordcard03_07_1.wav                         [16]                          NaN
#
#                     2022.04.06.15.34.12_36988952  \
# wordcard03_01.wav                           [16]
# wordcard03_01_1.wav                         [16]
# wordcard03_01_2.wav                         [16]
# wordcard03_02.wav                           [16]
# wordcard03_02_1.wav                         [16]
# wordcard03_02_2.wav                         [16]
# wordcard03_03.wav                           [16]
# wordcard03_03_1.wav                         [16]
# wordcard03_03_2.wav                         [16]
# wordcard03_04.wav                           [16]
# wordcard03_04_1.wav                         [16]
# wordcard03_04_2.wav                         [16]
# wordcard03_05.wav                           [16]
# wordcard03_05_1.wav                  [15, 16, 5]
# wordcard03_05_2.wav                         [16]
# wordcard03_06.wav                           [16]
# wordcard03_06_1.wav                         [16]
# wordcard03_06_2.wav                         [16]
# wordcard03_07.wav                           [16]
# wordcard03_07_1.wav                         [16]
#
#                     2022.04.07.09.35.40_27898863_test  \
# wordcard03_01.wav                                [16]
# wordcard03_01_1.wav                              [16]
# wordcard03_01_2.wav                              [16]
# wordcard03_02.wav                                [16]
# wordcard03_02_1.wav                              [16]
# wordcard03_02_2.wav                              [16]
# wordcard03_03.wav                                [16]
# wordcard03_03_1.wav                               [5]
# wordcard03_03_2.wav                              [16]
# wordcard03_04.wav                                [16]
# wordcard03_04_1.wav                               [5]
# wordcard03_04_2.wav                              [16]
# wordcard03_05.wav                                [16]
# wordcard03_05_1.wav                              [16]
# wordcard03_05_2.wav                              [16]
# wordcard03_06.wav                                [16]
# wordcard03_06_1.wav                              [16]
# wordcard03_06_2.wav                              [16]
# wordcard03_07.wav                                [16]
# wordcard03_07_1.wav                              [16]
#
#                     2022.04.07.13.45.02_42860780  \
# wordcard03_01.wav                           [16]
# wordcard03_01_1.wav                         [16]
# wordcard03_01_2.wav                         [16]
# wordcard03_02.wav                           [16]
# wordcard03_02_1.wav                         [16]
# wordcard03_02_2.wav                         [16]
# wordcard03_03.wav                           [16]
# wordcard03_03_1.wav                         [16]
# wordcard03_03_2.wav                         [16]
# wordcard03_04.wav                    [5, 10, 16]
# wordcard03_04_1.wav                         [16]
# wordcard03_04_2.wav                         [16]
# wordcard03_05.wav                           [16]
# wordcard03_05_1.wav                         [16]
# wordcard03_05_2.wav                         [16]
# wordcard03_06.wav                           [16]
# wordcard03_06_1.wav                         [16]
# wordcard03_06_2.wav                         [16]
# wordcard03_07.wav                           [16]
# wordcard03_07_1.wav                         [16]
#
#                     2022.04.08.08.44.36_111234296_test  \
# wordcard03_01.wav                                  [4]
# wordcard03_01_1.wav                               [16]
# wordcard03_01_2.wav                                [4]
# wordcard03_02.wav                                  [4]
# wordcard03_02_1.wav                               [16]
# wordcard03_02_2.wav                                [4]
# wordcard03_03.wav                                  [5]
# wordcard03_03_1.wav                                [5]
# wordcard03_03_2.wav                               [16]
# wordcard03_04.wav                                 [16]
# wordcard03_04_1.wav                               [16]
# wordcard03_04_2.wav                               [16]
# wordcard03_05.wav                           [1, 16, 5]
# wordcard03_05_1.wav                               [16]
# wordcard03_05_2.wav                               [16]
# wordcard03_06.wav                                 [15]
# wordcard03_06_1.wav                               [16]
# wordcard03_06_2.wav                               [10]
# wordcard03_07.wav                                  [4]
# wordcard03_07_1.wav                               [16]
#
#                     2022.04.08.09.42.57_114736422_test  \
# wordcard03_01.wav                                 [16]
# wordcard03_01_1.wav                                [5]
# wordcard03_01_2.wav                               [16]
# wordcard03_02.wav                                 [16]
# wordcard03_02_1.wav                               [16]
# wordcard03_02_2.wav                               [16]
# wordcard03_03.wav                           [16, 5, 1]
# wordcard03_03_1.wav                         [16, 5, 1]
# wordcard03_03_2.wav                               [16]
# wordcard03_04.wav                                  [5]
# wordcard03_04_1.wav                                [5]
# wordcard03_04_2.wav                               [16]
# wordcard03_05.wav                      [5, 16, 15, 17]
# wordcard03_05_1.wav                               [16]
# wordcard03_05_2.wav                               [15]
# wordcard03_06.wav                                 [16]
# wordcard03_06_1.wav                               [16]
# wordcard03_06_2.wav                               [16]
# wordcard03_07.wav                                 [16]
# wordcard03_07_1.wav                               [16]
#
#                     2022.04.08.10.00.15_115774292_test  \
# wordcard03_01.wav                                  [6]
# wordcard03_01_1.wav                               [16]
# wordcard03_01_2.wav                        [15, 6, 10]
# wordcard03_02.wav                                 [16]
# wordcard03_02_1.wav                               [16]
# wordcard03_02_2.wav                               [16]
# wordcard03_03.wav                                 [16]
# wordcard03_03_1.wav                               [16]
# wordcard03_03_2.wav                               [16]
# wordcard03_04.wav                                 [16]
# wordcard03_04_1.wav                               [16]
# wordcard03_04_2.wav                               [16]
# wordcard03_05.wav                                 [16]
# wordcard03_05_1.wav                               [16]
# wordcard03_05_2.wav                        [15, 6, 16]
# wordcard03_06.wav                                 [16]
# wordcard03_06_1.wav                               [16]
# wordcard03_06_2.wav                               [16]
# wordcard03_07.wav                                 [16]
# wordcard03_07_1.wav                               [16]
#
#                     2022.04.08.10.28.39_117478380_test  ...  \
# wordcard03_01.wav                                 [16]  ...
# wordcard03_01_1.wav                               [16]  ...
# wordcard03_01_2.wav                               [16]  ...
# wordcard03_02.wav                                 [16]  ...
# wordcard03_02_1.wav                               [16]  ...
# wordcard03_02_2.wav                               [16]  ...
# wordcard03_03.wav                                 [16]  ...
# wordcard03_03_1.wav                               [16]  ...
# wordcard03_03_2.wav                               [16]  ...
# wordcard03_04.wav                                 [16]  ...
# wordcard03_04_1.wav                               [16]  ...
# wordcard03_04_2.wav                               [16]  ...
# wordcard03_05.wav                                 [16]  ...
# wordcard03_05_1.wav                               [16]  ...
# wordcard03_05_2.wav                               [16]  ...
# wordcard03_06.wav                                 [16]  ...
# wordcard03_06_1.wav                               [16]  ...
# wordcard03_06_2.wav                               [16]  ...
# wordcard03_07.wav                          [16, 6, 15]  ...
# wordcard03_07_1.wav                               [16]  ...
#
#                     2022.08.11.13.47.46_1955476989_adult  \
# wordcard03_01.wav                                    [5]
# wordcard03_01_1.wav                                  [5]
# wordcard03_01_2.wav                                 [16]
# wordcard03_02.wav                                    [5]
# wordcard03_02_1.wav                                  [5]
# wordcard03_02_2.wav                                 [16]
# wordcard03_03.wav                                    [5]
# wordcard03_03_1.wav                                  [5]
# wordcard03_03_2.wav                                  [5]
# wordcard03_04.wav                                    [5]
# wordcard03_04_1.wav                                  [5]
# wordcard03_04_2.wav                                  [5]
# wordcard03_05.wav                                    [5]
# wordcard03_05_1.wav                                  [5]
# wordcard03_05_2.wav                                  [5]
# wordcard03_06.wav                                    [5]
# wordcard03_06_1.wav                                  [5]
# wordcard03_06_2.wav                                  [5]
# wordcard03_07.wav                                    [5]
# wordcard03_07_1.wav                                  [5]
#
#                     2022.08.11.14.03.38_1954525545_adult  \
# wordcard03_01.wav                                   [16]
# wordcard03_01_1.wav                                  [5]
# wordcard03_01_2.wav                                 [16]
# wordcard03_02.wav                                    [5]
# wordcard03_02_1.wav                                  [5]
# wordcard03_02_2.wav                                 [16]
# wordcard03_03.wav                                    [5]
# wordcard03_03_1.wav                                  [5]
# wordcard03_03_2.wav                                 [16]
# wordcard03_04.wav                                    [5]
# wordcard03_04_1.wav                                  [5]
# wordcard03_04_2.wav                                 [16]
# wordcard03_05.wav                                    [5]
# wordcard03_05_1.wav                                  [5]
# wordcard03_05_2.wav                                 [16]
# wordcard03_06.wav                                    [5]
# wordcard03_06_1.wav                                  [5]
# wordcard03_06_2.wav                                 [16]
# wordcard03_07.wav                                    [5]
# wordcard03_07_1.wav                                  [5]
#
#                     2022.08.11.15.06.19_1950764235_adult  \
# wordcard03_01.wav                                    [5]
# wordcard03_01_1.wav                                  [5]
# wordcard03_01_2.wav                                 [16]
# wordcard03_02.wav                                    [5]
# wordcard03_02_1.wav                                  [5]
# wordcard03_02_2.wav                                 [16]
# wordcard03_03.wav                                    [5]
# wordcard03_03_1.wav                                  [5]
# wordcard03_03_2.wav                                  [5]
# wordcard03_04.wav                                    [5]
# wordcard03_04_1.wav                                  [5]
# wordcard03_04_2.wav                                  [5]
# wordcard03_05.wav                                    [5]
# wordcard03_05_1.wav                                  [5]
# wordcard03_05_2.wav                                  [5]
# wordcard03_06.wav                                    [5]
# wordcard03_06_1.wav                                  [5]
# wordcard03_06_2.wav                                  [5]
# wordcard03_07.wav                                    [5]
# wordcard03_07_1.wav                                  [5]
#
#                     2022.08.11.15.24.53_1949650045_adult  \
# wordcard03_01.wav                                    [5]
# wordcard03_01_1.wav                                  [5]
# wordcard03_01_2.wav                                 [16]
# wordcard03_02.wav                                    [5]
# wordcard03_02_1.wav                                  [5]
# wordcard03_02_2.wav                                 [16]
# wordcard03_03.wav                                    [5]
# wordcard03_03_1.wav                                  [5]
# wordcard03_03_2.wav                                  [5]
# wordcard03_04.wav                                    [5]
# wordcard03_04_1.wav                                  [5]
# wordcard03_04_2.wav                                  [5]
# wordcard03_05.wav                                    [5]
# wordcard03_05_1.wav                                  [5]
# wordcard03_05_2.wav                                  [5]
# wordcard03_06.wav                                    [5]
# wordcard03_06_1.wav                                 [16]
# wordcard03_06_2.wav                                 [16]
# wordcard03_07.wav                                    [5]
# wordcard03_07_1.wav                                  [5]
#
#                     2022.08.11.15.35.06_1949037459_adult  \
# wordcard03_01.wav                                    [5]
# wordcard03_01_1.wav                                  [5]
# wordcard03_01_2.wav                                 [16]
# wordcard03_02.wav                                    [5]
# wordcard03_02_1.wav                                  [5]
# wordcard03_02_2.wav                                 [16]
# wordcard03_03.wav                                    [5]
# wordcard03_03_1.wav                                  [5]
# wordcard03_03_2.wav                                  [5]
# wordcard03_04.wav                                    [5]
# wordcard03_04_1.wav                                  [5]
# wordcard03_04_2.wav                                  [5]
# wordcard03_05.wav                                    [5]
# wordcard03_05_1.wav                                  [5]
# wordcard03_05_2.wav                                  [5]
# wordcard03_06.wav                                    [5]
# wordcard03_06_1.wav                                  [5]
# wordcard03_06_2.wav                                  [5]
# wordcard03_07.wav                                   [15]
# wordcard03_07_1.wav                                 [15]
#
#                     2022.08.11.15.44.07_1948496007_adult  \
# wordcard03_01.wav                                    [5]
# wordcard03_01_1.wav                                  [5]
# wordcard03_01_2.wav                                 [16]
# wordcard03_02.wav                                    [5]
# wordcard03_02_1.wav                                  [5]
# wordcard03_02_2.wav                                 [16]
# wordcard03_03.wav                                    [5]
# wordcard03_03_1.wav                                  [5]
# wordcard03_03_2.wav                                 [16]
# wordcard03_04.wav                                    [5]
# wordcard03_04_1.wav                                  [5]
# wordcard03_04_2.wav                                 [16]
# wordcard03_05.wav                                    [5]
# wordcard03_05_1.wav                                  [5]
# wordcard03_05_2.wav                                 [16]
# wordcard03_06.wav                                    [5]
# wordcard03_06_1.wav                                  [5]
# wordcard03_06_2.wav                                 [16]
# wordcard03_07.wav                                    [5]
# wordcard03_07_1.wav                                  [5]
#
#                     2022.08.11.15.59.36_1947567322_adult  \
# wordcard03_01.wav                                    [5]
# wordcard03_01_1.wav                                  [5]
# wordcard03_01_2.wav                                 [16]
# wordcard03_02.wav                                    [5]
# wordcard03_02_1.wav                                  [5]
# wordcard03_02_2.wav                                 [16]
# wordcard03_03.wav                                    [5]
# wordcard03_03_1.wav                                  [5]
# wordcard03_03_2.wav                                  [5]
# wordcard03_04.wav                                    [5]
# wordcard03_04_1.wav                                  [5]
# wordcard03_04_2.wav                                  [5]
# wordcard03_05.wav                                    [5]
# wordcard03_05_1.wav                                  [5]
# wordcard03_05_2.wav                                  [5]
# wordcard03_06.wav                                    [5]
# wordcard03_06_1.wav                                  [5]
# wordcard03_06_2.wav                                  [5]
# wordcard03_07.wav                                    [5]
# wordcard03_07_1.wav                                  [5]
#
#                     2022.08.11.17.11.20_1943263647_adult  \
# wordcard03_01.wav                                   [17]
# wordcard03_01_1.wav                                 [17]
# wordcard03_01_2.wav                                 [17]
# wordcard03_02.wav                                    [5]
# wordcard03_02_1.wav                                 [17]
# wordcard03_02_2.wav                                 [17]
# wordcard03_03.wav                                   [17]
# wordcard03_03_1.wav                                 [17]
# wordcard03_03_2.wav                                 [17]
# wordcard03_04.wav                                   [17]
# wordcard03_04_1.wav                                 [17]
# wordcard03_04_2.wav                                 [17]
# wordcard03_05.wav                                   [17]
# wordcard03_05_1.wav                                 [17]
# wordcard03_05_2.wav                                 [17]
# wordcard03_06.wav                                   [17]
# wordcard03_06_1.wav                                 [17]
# wordcard03_06_2.wav                                 [17]
# wordcard03_07.wav                                   [17]
# wordcard03_07_1.wav                                 [17]
#
#                     2022.08.11.17.19.36_1942766623_adult  \
# wordcard03_01.wav                                    [5]
# wordcard03_01_1.wav                                  [5]
# wordcard03_01_2.wav                                 [16]
# wordcard03_02.wav                                   [16]
# wordcard03_02_1.wav                                  [5]
# wordcard03_02_2.wav                                 [16]
# wordcard03_03.wav                                    [5]
# wordcard03_03_1.wav                                  [5]
# wordcard03_03_2.wav                                 [16]
# wordcard03_04.wav                                    [5]
# wordcard03_04_1.wav                                  [5]
# wordcard03_04_2.wav                                 [16]
# wordcard03_05.wav                                    [5]
# wordcard03_05_1.wav                                  [5]
# wordcard03_05_2.wav                                  [5]
# wordcard03_06.wav                                   [16]
# wordcard03_06_1.wav                                 [16]
# wordcard03_06_2.wav                                 [16]
# wordcard03_07.wav                                   [16]
# wordcard03_07_1.wav                                 [16]
#
#                     2022.08.11.17.27.37_1942285355_adult
# wordcard03_01.wav                                    [5]
# wordcard03_01_1.wav                                  [5]
# wordcard03_01_2.wav                                 [16]
# wordcard03_02.wav                                   [16]
# wordcard03_02_1.wav                                  [5]
# wordcard03_02_2.wav                                 [16]
# wordcard03_03.wav                                    [5]
# wordcard03_03_1.wav                                  [5]
# wordcard03_03_2.wav                                 [16]
# wordcard03_04.wav                                    [5]
# wordcard03_04_1.wav                                  [5]
# wordcard03_04_2.wav                                 [16]
# wordcard03_05.wav                                    [5]
# wordcard03_05_1.wav                                  [5]
# wordcard03_05_2.wav                                 [16]
# wordcard03_06.wav                                    [5]
# wordcard03_06_1.wav                                  [5]
# wordcard03_06_2.wav                                 [16]
# wordcard03_07.wav                                    [5]
# wordcard03_07_1.wav                                  [5]
#
# [20 rows x 59 columns]

# %% [markdown]
# ## stat_rename

# %%
save_json = 'class_number_'+DATE

# %%
classWordNumberChild = {
    "塞音化": 0,
    "母音化": 0,
    "母音省略": 0,
    "舌前音化": 0,
    "舌根音化": 0,
    "不送氣音化": 0,
    "聲隨韻母": 0,
    "邊音化": 0,
    "齒間音": 0,
    "子音省略": 0,
    "擦音化": 0,
    "介音省略": 0,
    "塞擦音化": 0,
    "複韻母省略": 0,
    "其他": 0,
    "正確": 0,
    "雜訊無法辨識": 0
}
classWordNumberAdult = {
    "塞音化": 0,
    "母音化": 0,
    "母音省略": 0,
    "舌前音化": 0,
    "舌根音化": 0,
    "不送氣音化": 0,
    "聲隨韻母": 0,
    "邊音化": 0,
    "齒間音": 0,
    "子音省略": 0,
    "擦音化": 0,
    "介音省略": 0,
    "塞擦音化": 0,
    "複韻母省略": 0,
    "其他": 0,
    "正確": 0,
    "雜訊無法辨識": 0
}
classSyllableNumberChild = {
    "塞音化": 0,
    "母音化": 0,
    "母音省略": 0,
    "舌前音化": 0,
    "舌根音化": 0,
    "不送氣音化": 0,
    "聲隨韻母": 0,
    "邊音化": 0,
    "齒間音": 0,
    "子音省略": 0,
    "擦音化": 0,
    "介音省略": 0,
    "塞擦音化": 0,
    "複韻母省略": 0,
    "其他": 0,
    "正確": 0,
    "雜訊無法辨識": 0
}
classSyllableNumberAdult = {
    "塞音化": 0,
    "母音化": 0,
    "母音省略": 0,
    "舌前音化": 0,
    "舌根音化": 0,
    "不送氣音化": 0,
    "聲隨韻母": 0,
    "邊音化": 0,
    "齒間音": 0,
    "子音省略": 0,
    "擦音化": 0,
    "介音省略": 0,
    "塞擦音化": 0,
    "複韻母省略": 0,
    "其他": 0,
    "正確": 0,
    "雜訊無法辨識": 0
}

# %%
df_stat.head(20)
# Out:
#                     2022.04.01.13.12.28_477493581  \
# wordcard03_01.wav                            [16]
# wordcard03_01_1.wav                          [16]
# wordcard03_01_2.wav                          [16]
# wordcard03_02.wav                            [16]
# wordcard03_02_1.wav                          [16]
# wordcard03_02_2.wav                          [16]
# wordcard03_03.wav                             [5]
# wordcard03_03_1.wav                           [5]
# wordcard03_03_2.wav                          [16]
# wordcard03_04.wav                            [16]
# wordcard03_04_1.wav                          [16]
# wordcard03_04_2.wav                          [16]
# wordcard03_05.wav                             [5]
# wordcard03_05_1.wav                           [5]
# wordcard03_05_2.wav                          [16]
# wordcard03_06.wav                            [16]
# wordcard03_06_1.wav                          [16]
# wordcard03_06_2.wav                          [16]
# wordcard03_07.wav                            [16]
# wordcard03_07_1.wav                          [16]
#
#                     2022.04.06.10.08.07_56554239 2022.04.06.14.09.10_42091033  \
# wordcard03_01.wav                           [16]                          [4]
# wordcard03_01_1.wav                         [16]                         [16]
# wordcard03_01_2.wav                         [11]                          [4]
# wordcard03_02.wav                           [16]                          [4]
# wordcard03_02_1.wav                         [16]                         [16]
# wordcard03_02_2.wav                         [16]                          [4]
# wordcard03_03.wav                           [16]                          NaN
# wordcard03_03_1.wav                         [16]                          NaN
# wordcard03_03_2.wav                         [16]                          NaN
# wordcard03_04.wav                           [16]                          NaN
# wordcard03_04_1.wav                         [16]                          NaN
# wordcard03_04_2.wav                         [16]                          NaN
# wordcard03_05.wav                           [16]                          NaN
# wordcard03_05_1.wav                         [16]                          NaN
# wordcard03_05_2.wav                         [16]                          NaN
# wordcard03_06.wav                           [16]                          NaN
# wordcard03_06_1.wav                         [16]                          NaN
# wordcard03_06_2.wav                         [16]                          NaN
# wordcard03_07.wav                           [16]                          NaN
# wordcard03_07_1.wav                         [16]                          NaN
#
#                     2022.04.06.15.34.12_36988952  \
# wordcard03_01.wav                           [16]
# wordcard03_01_1.wav                         [16]
# wordcard03_01_2.wav                         [16]
# wordcard03_02.wav                           [16]
# wordcard03_02_1.wav                         [16]
# wordcard03_02_2.wav                         [16]
# wordcard03_03.wav                           [16]
# wordcard03_03_1.wav                         [16]
# wordcard03_03_2.wav                         [16]
# wordcard03_04.wav                           [16]
# wordcard03_04_1.wav                         [16]
# wordcard03_04_2.wav                         [16]
# wordcard03_05.wav                           [16]
# wordcard03_05_1.wav                  [15, 16, 5]
# wordcard03_05_2.wav                         [16]
# wordcard03_06.wav                           [16]
# wordcard03_06_1.wav                         [16]
# wordcard03_06_2.wav                         [16]
# wordcard03_07.wav                           [16]
# wordcard03_07_1.wav                         [16]
#
#                     2022.04.07.09.35.40_27898863_test  \
# wordcard03_01.wav                                [16]
# wordcard03_01_1.wav                              [16]
# wordcard03_01_2.wav                              [16]
# wordcard03_02.wav                                [16]
# wordcard03_02_1.wav                              [16]
# wordcard03_02_2.wav                              [16]
# wordcard03_03.wav                                [16]
# wordcard03_03_1.wav                               [5]
# wordcard03_03_2.wav                              [16]
# wordcard03_04.wav                                [16]
# wordcard03_04_1.wav                               [5]
# wordcard03_04_2.wav                              [16]
# wordcard03_05.wav                                [16]
# wordcard03_05_1.wav                              [16]
# wordcard03_05_2.wav                              [16]
# wordcard03_06.wav                                [16]
# wordcard03_06_1.wav                              [16]
# wordcard03_06_2.wav                              [16]
# wordcard03_07.wav                                [16]
# wordcard03_07_1.wav                              [16]
#
#                     2022.04.07.13.45.02_42860780  \
# wordcard03_01.wav                           [16]
# wordcard03_01_1.wav                         [16]
# wordcard03_01_2.wav                         [16]
# wordcard03_02.wav                           [16]
# wordcard03_02_1.wav                         [16]
# wordcard03_02_2.wav                         [16]
# wordcard03_03.wav                           [16]
# wordcard03_03_1.wav                         [16]
# wordcard03_03_2.wav                         [16]
# wordcard03_04.wav                    [5, 10, 16]
# wordcard03_04_1.wav                         [16]
# wordcard03_04_2.wav                         [16]
# wordcard03_05.wav                           [16]
# wordcard03_05_1.wav                         [16]
# wordcard03_05_2.wav                         [16]
# wordcard03_06.wav                           [16]
# wordcard03_06_1.wav                         [16]
# wordcard03_06_2.wav                         [16]
# wordcard03_07.wav                           [16]
# wordcard03_07_1.wav                         [16]
#
#                     2022.04.08.08.44.36_111234296_test  \
# wordcard03_01.wav                                  [4]
# wordcard03_01_1.wav                               [16]
# wordcard03_01_2.wav                                [4]
# wordcard03_02.wav                                  [4]
# wordcard03_02_1.wav                               [16]
# wordcard03_02_2.wav                                [4]
# wordcard03_03.wav                                  [5]
# wordcard03_03_1.wav                                [5]
# wordcard03_03_2.wav                               [16]
# wordcard03_04.wav                                 [16]
# wordcard03_04_1.wav                               [16]
# wordcard03_04_2.wav                               [16]
# wordcard03_05.wav                           [1, 16, 5]
# wordcard03_05_1.wav                               [16]
# wordcard03_05_2.wav                               [16]
# wordcard03_06.wav                                 [15]
# wordcard03_06_1.wav                               [16]
# wordcard03_06_2.wav                               [10]
# wordcard03_07.wav                                  [4]
# wordcard03_07_1.wav                               [16]
#
#                     2022.04.08.09.42.57_114736422_test  \
# wordcard03_01.wav                                 [16]
# wordcard03_01_1.wav                                [5]
# wordcard03_01_2.wav                               [16]
# wordcard03_02.wav                                 [16]
# wordcard03_02_1.wav                               [16]
# wordcard03_02_2.wav                               [16]
# wordcard03_03.wav                           [16, 5, 1]
# wordcard03_03_1.wav                         [16, 5, 1]
# wordcard03_03_2.wav                               [16]
# wordcard03_04.wav                                  [5]
# wordcard03_04_1.wav                                [5]
# wordcard03_04_2.wav                               [16]
# wordcard03_05.wav                      [5, 16, 15, 17]
# wordcard03_05_1.wav                               [16]
# wordcard03_05_2.wav                               [15]
# wordcard03_06.wav                                 [16]
# wordcard03_06_1.wav                               [16]
# wordcard03_06_2.wav                               [16]
# wordcard03_07.wav                                 [16]
# wordcard03_07_1.wav                               [16]
#
#                     2022.04.08.10.00.15_115774292_test  \
# wordcard03_01.wav                                  [6]
# wordcard03_01_1.wav                               [16]
# wordcard03_01_2.wav                        [15, 6, 10]
# wordcard03_02.wav                                 [16]
# wordcard03_02_1.wav                               [16]
# wordcard03_02_2.wav                               [16]
# wordcard03_03.wav                                 [16]
# wordcard03_03_1.wav                               [16]
# wordcard03_03_2.wav                               [16]
# wordcard03_04.wav                                 [16]
# wordcard03_04_1.wav                               [16]
# wordcard03_04_2.wav                               [16]
# wordcard03_05.wav                                 [16]
# wordcard03_05_1.wav                               [16]
# wordcard03_05_2.wav                        [15, 6, 16]
# wordcard03_06.wav                                 [16]
# wordcard03_06_1.wav                               [16]
# wordcard03_06_2.wav                               [16]
# wordcard03_07.wav                                 [16]
# wordcard03_07_1.wav                               [16]
#
#                     2022.04.08.10.28.39_117478380_test  ...  \
# wordcard03_01.wav                                 [16]  ...
# wordcard03_01_1.wav                               [16]  ...
# wordcard03_01_2.wav                               [16]  ...
# wordcard03_02.wav                                 [16]  ...
# wordcard03_02_1.wav                               [16]  ...
# wordcard03_02_2.wav                               [16]  ...
# wordcard03_03.wav                                 [16]  ...
# wordcard03_03_1.wav                               [16]  ...
# wordcard03_03_2.wav                               [16]  ...
# wordcard03_04.wav                                 [16]  ...
# wordcard03_04_1.wav                               [16]  ...
# wordcard03_04_2.wav                               [16]  ...
# wordcard03_05.wav                                 [16]  ...
# wordcard03_05_1.wav                               [16]  ...
# wordcard03_05_2.wav                               [16]  ...
# wordcard03_06.wav                                 [16]  ...
# wordcard03_06_1.wav                               [16]  ...
# wordcard03_06_2.wav                               [16]  ...
# wordcard03_07.wav                          [16, 6, 15]  ...
# wordcard03_07_1.wav                               [16]  ...
#
#                     2022.08.11.13.47.46_1955476989_adult  \
# wordcard03_01.wav                                    [5]
# wordcard03_01_1.wav                                  [5]
# wordcard03_01_2.wav                                 [16]
# wordcard03_02.wav                                    [5]
# wordcard03_02_1.wav                                  [5]
# wordcard03_02_2.wav                                 [16]
# wordcard03_03.wav                                    [5]
# wordcard03_03_1.wav                                  [5]
# wordcard03_03_2.wav                                  [5]
# wordcard03_04.wav                                    [5]
# wordcard03_04_1.wav                                  [5]
# wordcard03_04_2.wav                                  [5]
# wordcard03_05.wav                                    [5]
# wordcard03_05_1.wav                                  [5]
# wordcard03_05_2.wav                                  [5]
# wordcard03_06.wav                                    [5]
# wordcard03_06_1.wav                                  [5]
# wordcard03_06_2.wav                                  [5]
# wordcard03_07.wav                                    [5]
# wordcard03_07_1.wav                                  [5]
#
#                     2022.08.11.14.03.38_1954525545_adult  \
# wordcard03_01.wav                                   [16]
# wordcard03_01_1.wav                                  [5]
# wordcard03_01_2.wav                                 [16]
# wordcard03_02.wav                                    [5]
# wordcard03_02_1.wav                                  [5]
# wordcard03_02_2.wav                                 [16]
# wordcard03_03.wav                                    [5]
# wordcard03_03_1.wav                                  [5]
# wordcard03_03_2.wav                                 [16]
# wordcard03_04.wav                                    [5]
# wordcard03_04_1.wav                                  [5]
# wordcard03_04_2.wav                                 [16]
# wordcard03_05.wav                                    [5]
# wordcard03_05_1.wav                                  [5]
# wordcard03_05_2.wav                                 [16]
# wordcard03_06.wav                                    [5]
# wordcard03_06_1.wav                                  [5]
# wordcard03_06_2.wav                                 [16]
# wordcard03_07.wav                                    [5]
# wordcard03_07_1.wav                                  [5]
#
#                     2022.08.11.15.06.19_1950764235_adult  \
# wordcard03_01.wav                                    [5]
# wordcard03_01_1.wav                                  [5]
# wordcard03_01_2.wav                                 [16]
# wordcard03_02.wav                                    [5]
# wordcard03_02_1.wav                                  [5]
# wordcard03_02_2.wav                                 [16]
# wordcard03_03.wav                                    [5]
# wordcard03_03_1.wav                                  [5]
# wordcard03_03_2.wav                                  [5]
# wordcard03_04.wav                                    [5]
# wordcard03_04_1.wav                                  [5]
# wordcard03_04_2.wav                                  [5]
# wordcard03_05.wav                                    [5]
# wordcard03_05_1.wav                                  [5]
# wordcard03_05_2.wav                                  [5]
# wordcard03_06.wav                                    [5]
# wordcard03_06_1.wav                                  [5]
# wordcard03_06_2.wav                                  [5]
# wordcard03_07.wav                                    [5]
# wordcard03_07_1.wav                                  [5]
#
#                     2022.08.11.15.24.53_1949650045_adult  \
# wordcard03_01.wav                                    [5]
# wordcard03_01_1.wav                                  [5]
# wordcard03_01_2.wav                                 [16]
# wordcard03_02.wav                                    [5]
# wordcard03_02_1.wav                                  [5]
# wordcard03_02_2.wav                                 [16]
# wordcard03_03.wav                                    [5]
# wordcard03_03_1.wav                                  [5]
# wordcard03_03_2.wav                                  [5]
# wordcard03_04.wav                                    [5]
# wordcard03_04_1.wav                                  [5]
# wordcard03_04_2.wav                                  [5]
# wordcard03_05.wav                                    [5]
# wordcard03_05_1.wav                                  [5]
# wordcard03_05_2.wav                                  [5]
# wordcard03_06.wav                                    [5]
# wordcard03_06_1.wav                                 [16]
# wordcard03_06_2.wav                                 [16]
# wordcard03_07.wav                                    [5]
# wordcard03_07_1.wav                                  [5]
#
#                     2022.08.11.15.35.06_1949037459_adult  \
# wordcard03_01.wav                                    [5]
# wordcard03_01_1.wav                                  [5]
# wordcard03_01_2.wav                                 [16]
# wordcard03_02.wav                                    [5]
# wordcard03_02_1.wav                                  [5]
# wordcard03_02_2.wav                                 [16]
# wordcard03_03.wav                                    [5]
# wordcard03_03_1.wav                                  [5]
# wordcard03_03_2.wav                                  [5]
# wordcard03_04.wav                                    [5]
# wordcard03_04_1.wav                                  [5]
# wordcard03_04_2.wav                                  [5]
# wordcard03_05.wav                                    [5]
# wordcard03_05_1.wav                                  [5]
# wordcard03_05_2.wav                                  [5]
# wordcard03_06.wav                                    [5]
# wordcard03_06_1.wav                                  [5]
# wordcard03_06_2.wav                                  [5]
# wordcard03_07.wav                                   [15]
# wordcard03_07_1.wav                                 [15]
#
#                     2022.08.11.15.44.07_1948496007_adult  \
# wordcard03_01.wav                                    [5]
# wordcard03_01_1.wav                                  [5]
# wordcard03_01_2.wav                                 [16]
# wordcard03_02.wav                                    [5]
# wordcard03_02_1.wav                                  [5]
# wordcard03_02_2.wav                                 [16]
# wordcard03_03.wav                                    [5]
# wordcard03_03_1.wav                                  [5]
# wordcard03_03_2.wav                                 [16]
# wordcard03_04.wav                                    [5]
# wordcard03_04_1.wav                                  [5]
# wordcard03_04_2.wav                                 [16]
# wordcard03_05.wav                                    [5]
# wordcard03_05_1.wav                                  [5]
# wordcard03_05_2.wav                                 [16]
# wordcard03_06.wav                                    [5]
# wordcard03_06_1.wav                                  [5]
# wordcard03_06_2.wav                                 [16]
# wordcard03_07.wav                                    [5]
# wordcard03_07_1.wav                                  [5]
#
#                     2022.08.11.15.59.36_1947567322_adult  \
# wordcard03_01.wav                                    [5]
# wordcard03_01_1.wav                                  [5]
# wordcard03_01_2.wav                                 [16]
# wordcard03_02.wav                                    [5]
# wordcard03_02_1.wav                                  [5]
# wordcard03_02_2.wav                                 [16]
# wordcard03_03.wav                                    [5]
# wordcard03_03_1.wav                                  [5]
# wordcard03_03_2.wav                                  [5]
# wordcard03_04.wav                                    [5]
# wordcard03_04_1.wav                                  [5]
# wordcard03_04_2.wav                                  [5]
# wordcard03_05.wav                                    [5]
# wordcard03_05_1.wav                                  [5]
# wordcard03_05_2.wav                                  [5]
# wordcard03_06.wav                                    [5]
# wordcard03_06_1.wav                                  [5]
# wordcard03_06_2.wav                                  [5]
# wordcard03_07.wav                                    [5]
# wordcard03_07_1.wav                                  [5]
#
#                     2022.08.11.17.11.20_1943263647_adult  \
# wordcard03_01.wav                                   [17]
# wordcard03_01_1.wav                                 [17]
# wordcard03_01_2.wav                                 [17]
# wordcard03_02.wav                                    [5]
# wordcard03_02_1.wav                                 [17]
# wordcard03_02_2.wav                                 [17]
# wordcard03_03.wav                                   [17]
# wordcard03_03_1.wav                                 [17]
# wordcard03_03_2.wav                                 [17]
# wordcard03_04.wav                                   [17]
# wordcard03_04_1.wav                                 [17]
# wordcard03_04_2.wav                                 [17]
# wordcard03_05.wav                                   [17]
# wordcard03_05_1.wav                                 [17]
# wordcard03_05_2.wav                                 [17]
# wordcard03_06.wav                                   [17]
# wordcard03_06_1.wav                                 [17]
# wordcard03_06_2.wav                                 [17]
# wordcard03_07.wav                                   [17]
# wordcard03_07_1.wav                                 [17]
#
#                     2022.08.11.17.19.36_1942766623_adult  \
# wordcard03_01.wav                                    [5]
# wordcard03_01_1.wav                                  [5]
# wordcard03_01_2.wav                                 [16]
# wordcard03_02.wav                                   [16]
# wordcard03_02_1.wav                                  [5]
# wordcard03_02_2.wav                                 [16]
# wordcard03_03.wav                                    [5]
# wordcard03_03_1.wav                                  [5]
# wordcard03_03_2.wav                                 [16]
# wordcard03_04.wav                                    [5]
# wordcard03_04_1.wav                                  [5]
# wordcard03_04_2.wav                                 [16]
# wordcard03_05.wav                                    [5]
# wordcard03_05_1.wav                                  [5]
# wordcard03_05_2.wav                                  [5]
# wordcard03_06.wav                                   [16]
# wordcard03_06_1.wav                                 [16]
# wordcard03_06_2.wav                                 [16]
# wordcard03_07.wav                                   [16]
# wordcard03_07_1.wav                                 [16]
#
#                     2022.08.11.17.27.37_1942285355_adult
# wordcard03_01.wav                                    [5]
# wordcard03_01_1.wav                                  [5]
# wordcard03_01_2.wav                                 [16]
# wordcard03_02.wav                                   [16]
# wordcard03_02_1.wav                                  [5]
# wordcard03_02_2.wav                                 [16]
# wordcard03_03.wav                                    [5]
# wordcard03_03_1.wav                                  [5]
# wordcard03_03_2.wav                                 [16]
# wordcard03_04.wav                                    [5]
# wordcard03_04_1.wav                                  [5]
# wordcard03_04_2.wav                                 [16]
# wordcard03_05.wav                                    [5]
# wordcard03_05_1.wav                                  [5]
# wordcard03_05_2.wav                                 [16]
# wordcard03_06.wav                                    [5]
# wordcard03_06_1.wav                                  [5]
# wordcard03_06_2.wav                                 [16]
# wordcard03_07.wav                                    [5]
# wordcard03_07_1.wav                                  [5]
#
# [20 rows x 59 columns]

# %%
def copy(src, destination):
    if(os.path.exists(src)):
        tmp = os.path.splitext(destination)[0]
        tmpend = tmp.split('/')
        index = tmp.find(tmpend[-1])
        if not os.path.isdir(destination[:index]):
            os.makedirs(destination[:index])
        # print(src, destination)
        # print(destination[:index])
        shutil.copyfile(src, destination)
    else:
        print(f"{src} not found")


def isWord(wordcard):
    if(len(wordcard.split('_')) == 2):  # if the wordcard is WORD
        return True
    return False


def isAdult(case):
    if(case.split('_')[-1] == 'adult'):
        return True
    return False


    

def newpath_class_plusOne(ISWORD, ISADULT, TARGET, ISFCDP):
    if(ISWORD):
        if(ISADULT):
            classWordNumberAdult[TARGET] += 1
            tmpPath = FCDPWORDPATH + \
                "adult/" if (ISFCDP) else WORDPATH+"adult/"
            
        else:
            classWordNumberChild[TARGET] += 1
            tmpPath = FCDPWORDPATH + \
                "child/" if (ISFCDP) else WORDPATH+"child/"
    else:
        if(ISADULT):
            classSyllableNumberAdult[TARGET] += 1
            tmpPath = FCDPSYLLABLEPATH + \
                "adult/" if (ISFCDP) else SYLLABLEPATH+"adult/"
        else:
            classSyllableNumberChild[TARGET] += 1
            tmpPath = FCDPSYLLABLEPATH + \
                "child/" if (ISFCDP) else SYLLABLEPATH+"child/"
    return tmpPath

# %%
error_lsit = [1,5,7,13]
CORRECT = '正確'
for case in df_stat.columns.tolist():
    for wordcard in df_stat.index.tolist():
        ISWORD = isWord(wordcard)
        ISFCDP = False
        if not df_stat[case][wordcard]: # if the value is empty
            pass
        elif (df_stat[case][wordcard] != df_stat[case][wordcard]): # if the value is NaN
            pass
        else:
            # print(wordcard, case, ISWORD)
            # if the case is adult(2022.05.15.19.58.12_946516734_adult)
            ISADULT = isAdult(case)
            case_number = case.split('_')[1]
            if (17 in df_stat[case][wordcard]):
                pass
            elif(16 in df_stat[case][wordcard]):
                # print(f"{DATAPATH}{case}/{wordcard}")
                # '/D/TWCC/data2022_ori/data_0327word/0401_0707/2022.06.16.09.33.28_1780799170_test/wordcard05_07_1.wav'
                oldFilePath = DATAPATH+case+'/'+wordcard
                # '/D/TWCC/data2022_ori/data_0327word/0401_0707/2022.06.16.09.33.28_1780799170_test/wordcard05_07_1'
                filePath = os.path.splitext(oldFilePath)[0]
                oldFileName = filePath.split('/')[-1]  # 'wordcard05_07_1'
                newFileName = "16_" + \
                    str(case_number) + '_' + oldFileName.split('wordcard')[1] + '.wav'
                if("fcdp" in wordcard):
                    ISFCDP = True
                tmpPath = newpath_class_plusOne(ISWORD, ISADULT, CORRECT, ISFCDP)
                newFilePath = os.path.join(tmpPath, newFileName)
                # print(f"{oldFilePath} -> {newFilePath}")
                # copy(oldFilePath, newFilePath)
                # shutil.copyfile(oldFilePath, newFilePath)
            else:
                for idx in error_lsit:
                    if(idx in df_stat[case][wordcard]):
                        error_idx = idx -1
                        # '/D/TWCC/data2022_ori/data_0327word/0401_0707/2022.06.16.09.33.28_1780799170_test/wordcard05_07_1.wav'
                        oldFilePath = DATAPATH+case+'/'+wordcard
                        # '/D/TWCC/data2022_ori/data_0327word/0401_0707/2022.06.16.09.33.28_1780799170_test/wordcard05_07_1'
                        filePath = os.path.splitext(oldFilePath)[0]
                        oldFileName = filePath.split('/')[-1]  # 'wordcard05_07_1'
                        newFileName = str(idx)+"_" + \
                            str(case_number) + '_' + \
                            oldFileName.split('wordcard')[1] + '.wav'
                        if("fcdp" in wordcard):
                            ISFCDP = True
                            if(idx != 7):
                                pass
                            else:
                                tmpPath = newpath_class_plusOne(ISWORD, ISADULT, class_name[error_idx], ISFCDP)
                                newFilePath = os.path.join(tmpPath, newFileName)
                                # print(f"{oldFilePath} -> {newFilePath}")
                                # copy(oldFilePath, newFilePath)
                                # shutil.copyfile(oldFilePath, newFilePath)
                        else:
                            if(idx != 7):
                                tmpPath = newpath_class_plusOne(ISWORD, ISADULT, class_name[error_idx], ISFCDP)
                                newFilePath = os.path.join(tmpPath, newFileName)
                                # print(f"{oldFilePath} -> {newFilePath}")
                                # copy(oldFilePath, newFilePath)
                                # shutil.copyfile(oldFilePath, newFilePath)
                

                # print(newFileName)
                # shutil.copyfile(oldFilePath, DATASETPATH+newFileName)

# %%
classWordNumberChild
# Out:
# {'塞音化': 78,
#  '母音化': 0,
#  '母音省略': 0,
#  '舌前音化': 0,
#  '舌根音化': 56,
#  '不送氣音化': 0,
#  '聲隨韻母': 34,
#  '邊音化': 0,
#  '齒間音': 0,
#  '子音省略': 0,
#  '擦音化': 0,
#  '介音省略': 0,
#  '塞擦音化': 36,
#  '複韻母省略': 0,
#  '其他': 0,
#  '正確': 340,
#  '雜訊無法辨識': 0}

# %%
classWordNumberAdult
# Out:
# {'塞音化': 0,
#  '母音化': 0,
#  '母音省略': 0,
#  '舌前音化': 0,
#  '舌根音化': 231,
#  '不送氣音化': 0,
#  '聲隨韻母': 1,
#  '邊音化': 0,
#  '齒間音': 0,
#  '子音省略': 0,
#  '擦音化': 0,
#  '介音省略': 0,
#  '塞擦音化': 2,
#  '複韻母省略': 0,
#  '其他': 0,
#  '正確': 415,
#  '雜訊無法辨識': 0}

# %%
classSyllableNumberChild
# Out:
# {'塞音化': 99,
#  '母音化': 0,
#  '母音省略': 0,
#  '舌前音化': 0,
#  '舌根音化': 112,
#  '不送氣音化': 0,
#  '聲隨韻母': 69,
#  '邊音化': 0,
#  '齒間音': 0,
#  '子音省略': 0,
#  '擦音化': 0,
#  '介音省略': 0,
#  '塞擦音化': 44,
#  '複韻母省略': 0,
#  '其他': 0,
#  '正確': 782,
#  '雜訊無法辨識': 0}

# %%
classSyllableNumberAdult
# Out:
# {'塞音化': 2,
#  '母音化': 0,
#  '母音省略': 0,
#  '舌前音化': 0,
#  '舌根音化': 313,
#  '不送氣音化': 0,
#  '聲隨韻母': 1,
#  '邊音化': 0,
#  '齒間音': 0,
#  '子音省略': 0,
#  '擦音化': 0,
#  '介音省略': 0,
#  '塞擦音化': 0,
#  '複韻母省略': 0,
#  '其他': 0,
#  '正確': 937,
#  '雜訊無法辨識': 0}

# %%
with open(DATASETPATH+save_json+'_word_child.json', 'w', encoding='utf-8') as f:
    json.dump(classWordNumberChild, f, ensure_ascii=False, indent=4)
    f.close()

with open(DATASETPATH+save_json+'_word_adult.json', 'w', encoding='utf-8') as f:
    json.dump(classWordNumberAdult, f, ensure_ascii=False, indent=4)
    f.close()

with open(DATASETPATH+save_json+'_syllable_child.json', 'w', encoding='utf-8') as f:
    json.dump(classSyllableNumberChild, f, ensure_ascii=False, indent=4)
    f.close()

with open(DATASETPATH+save_json+'_syllable_adult.json', 'w', encoding='utf-8') as f:
    json.dump(classSyllableNumberAdult, f, ensure_ascii=False, indent=4)
    f.close()
